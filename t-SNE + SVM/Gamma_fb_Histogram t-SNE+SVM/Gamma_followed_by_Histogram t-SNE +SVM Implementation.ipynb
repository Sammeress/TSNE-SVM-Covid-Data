# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.model_selection import train_test_split

# %%
#Import scikitlearn for machine learning functionalities
import sklearn
from sklearn.manifold import TSNE 

# Import matplotlib for plotting graphs ans seaborn for attractive graphics.
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe

import seaborn as sb

# %%
import sklearn.metrics as sm
from sklearn.svm import SVC

# %%
def calc_accuracy(method, label_test, predIdxs):
    print("\n\nACCURACY Score for ", method, sm.accuracy_score(label_test, predIdxs))

# %%
def predict_svm(X_train, X_test, y_train, y_test):
    svc = SVC(kernel='linear')
    print("\nTraining of SVM started")
    svc.fit(X_train, y_train)
    y_pred = svc.predict(X_test)
    calc_accuracy("SVM", y_test, y_pred)

# %% [markdown]
# ###RSNA (N) and CheXpert (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/RSNA/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Chexpert/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(10, 10))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ef6fa250>,
#  [Text(0.828676, 1.5199113, '0'),
#   Text(-2.488086, -2.296812, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.675

# %% [markdown]
# ###RSNA (P) and CheXpert (P)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/RSNA/Pneumonia"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Chexpert/Pneumonia"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(10, 10))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ef6e33d0>,
#  [Text(-0.15371066, 0.032110326, '0'),
#   Text(0.29656804, 0.024981875, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.725

# %% [markdown]
# ###Montgomery (N) and Shenzhen (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Montgomery/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Shenzhen/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 80
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 256, 256, 3)
# (280,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 196608)
# (280, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec84cf10>,
#  [Text(9.886589, -18.516764, '0'),
#   Text(-2.0072663, 2.6800475, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 252

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 28

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 1.0

# %% [markdown]
# ###Montgomery (O) and Shenzhen (O)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Montgomery/Other"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Shenzhen/Other"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 58
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (258, 256, 256, 3)
# (258,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (258, 196608)
# (258, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec7fa750>,
#  [Text(14.189705, -5.3891535, '0'),
#   Text(-2.4346893, 0.99395573, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 232

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 26

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 1.0

# %% [markdown]
# ###CheXpert (N) and Montgomery (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Chexpert/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Montgomery/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 80

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 256, 256, 3)
# (280,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 196608)
# (280, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec71ae10>,
#  [Text(-4.0852165, 2.525148, '0'),
#   Text(17.42466, -13.927731, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 252

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 28

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 1.0

# %% [markdown]
# ###CheXpert (N) and Shenzhen (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Chexpert/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Shenzhen/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec729290>,
#  [Text(0.4442945, 12.149688, '0'),
#   Text(-1.637363, -7.1779213, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.975

# %% [markdown]
# ###RSNA (N) and Montgomery (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/RSNA/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Montgomery/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 80

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 256, 256, 3)
# (280,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (280, 196608)
# (280, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec645b10>,
#  [Text(-12.687946, -15.379469, '0'),
#   Text(2.6173813, 3.1293745, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 252

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 28

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.9642857142857143

# %% [markdown]
# ###RSNA (N) and Shenzhen (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/RSNA/Normal"
test_pneumonia_dataset_path = "/content/drive/MyDrive/CXR/FINAL_CXR/Preprocessing/New_preprocess_gamma_fb_histogram/Shenzhen/Normal"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 200
# 200

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-3]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((data.shape[0], 256*256*3))
labels = labels.reshape((data.shape[0], 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f57ec5f16d0>,
#  [Text(-4.1771746, -11.635372, '0'),
#   Text(1.3133233, 5.711076, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.975
