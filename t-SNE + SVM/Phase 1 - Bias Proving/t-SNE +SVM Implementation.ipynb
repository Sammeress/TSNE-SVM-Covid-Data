# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.model_selection import train_test_split

# %%
#Import scikitlearn for machine learning functionalities
import sklearn
from sklearn.manifold import TSNE 

# Import matplotlib for plotting graphs ans seaborn for attractive graphics.
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

import seaborn as sb

# %%
import sklearn.metrics as sm
from sklearn.svm import SVC

# %%
def calc_accuracy(method, label_test, predIdxs):
    
    print("\n\nACCURACY Score for ", method, sm.accuracy_score(label_test, predIdxs))

# %%
def predict_svm(X_train, X_test, y_train, y_test):
    
    svc = SVC(kernel='linear')
    
    print("\nTraining of SVM started")
    
    svc.fit(X_train, y_train)
    
    y_pred = svc.predict(X_test)
    
    calc_accuracy("SVM", y_test, y_pred)

# %% [markdown]
# ###Paul (N) and CheXpert (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/Kaggle_PaulMooney/train/NORMAL"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/CheXpert/train/NORMAL"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 1083
# 13528

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(10, 10))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6fcbf7ad0>,
#  [Text(10.094919, -12.937876, '0'),
#   Text(-10.731138, 14.628355, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 1.0

# %% [markdown]
# ###Paul (N) and RSNA (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/Kaggle_PaulMooney/train/NORMAL"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/RSNA/train/NORMAL"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 1083
# 20172

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(10, 10))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6fbaa5650>,
#  [Text(-15.759408, 9.143423, '0'),
#   Text(16.700241, -10.607145, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.975

# %% [markdown]
# ###RSNA (N) and CheXpert (N)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/RSNA/train/NORMAL"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/CheXpert/train/NORMAL"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 20172
# 13528

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6f9bdff10>,
#  [Text(0.21331362, 3.3605704, '0'),
#   Text(2.0213923, 0.5222411, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.9

# %% [markdown]
# ###Paul (P) and CheXpert (P)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/Kaggle_PaulMooney/train/PNEUMONIA"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/CheXpert/train/PNEUMONIA"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 3773
# 3435

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6f9b96550>,
#  [Text(-8.228903, 12.574527, '0'),
#   Text(7.254895, -11.205576, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 1.0

# %% [markdown]
# ###Paul (P) and RSNA (P)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/Kaggle_PaulMooney/train/PNEUMONIA"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/RSNA/train/PNEUMONIA"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 3773
# 5512

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6f98c29d0>,
#  [Text(9.130236, -7.788745, '0'),
#   Text(-7.5778117, 8.780157, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.975

# %% [markdown]
# ###RSNA (P) and CheXpert (P)

# %%
# Path for the Testing Dataset
test_normal_dataset_path = "/content/drive/MyDrive/FINAL_CXR/RSNA/train/PNEUMONIA"
test_pneumonia_dataset_path = "/content/drive/MyDrive/FINAL_CXR/CheXpert/train/PNEUMONIA"

# %%
normal_imagePaths = list(paths.list_images(test_normal_dataset_path))
pneumonia_imagePaths = list(paths.list_images(test_pneumonia_dataset_path))

# %%
# Total Images for Training
print(len(normal_imagePaths))
print(len(pneumonia_imagePaths))
# Out:
# 5512
# 3435

# %%
normal_imagePaths = normal_imagePaths[:200]
pneumonia_imagePaths = pneumonia_imagePaths[:200]

# %%
imagePaths = []

# %%
for imagePath in normal_imagePaths:
  imagePaths.append(imagePath)

# %%
for imagePath in pneumonia_imagePaths:
  imagePaths.append(imagePath)

# %%
data = []   # List that will contain numpy arrays having pixel values of different images
labels = []  # List that will contain corresponding labels

# loop over the image paths
for imagePath in imagePaths:

    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-4]
    # Load the image, swap color channels, and resize it to be a fixed 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))
    # Update the data and labels lists, respectively
    data.append(image)
    labels.append(label)

# %%
# convert the data and labels to NumPy arrays while scaling the pixel intensities to the range [0, 1]
data = np.array(data) / 255.0   # Normalisation of data
labels = np.array(labels)

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 256, 256, 3)
# (400,)

# %%
data = data.reshape((400, 256*256*3))
labels = labels.reshape((400, 1))

# %%
# Shape of array data and labels
print(data.shape)
print(labels.shape)
# Out:
# (400, 196608)
# (400, 1)

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
classes = label_encoder.fit_transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
digits_final = TSNE(perplexity=30, random_state=101).fit_transform(data)

# %%
def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts

# %%
plot(digits_final, classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb6f9c58250>,
#  [Text(1.3662733, -2.7437794, '0'),
#   Text(0.13138807, 1.5960606, '1'),
#   Text(nan, nan, '2'),
#   Text(nan, nan, '3'),
#   Text(nan, nan, '4'),
#   Text(nan, nan, '5'),
#   Text(nan, nan, '6'),
#   Text(nan, nan, '7'),
#   Text(nan, nan, '8'),
#   Text(nan, nan, '9')])
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# For storing the class labels for Training and Validation datasets
train_class_list = []
val_class_list = []

# For storing the paths of images for Training and Validation datasets
train_data_list = []
val_data_list = []

# %%
# Training and Validation split
(train_data_list, val_data_list, train_class_list, val_class_list) = train_test_split(data,
                                                                                      classes,
                                                                                      test_size = 0.1,
                                                                                      stratify = classes,
                                                                                      random_state = 101)

# %%
# Images for Training set
len(train_data_list)
# Out:
# 360

# %%
# Images for Validation set
len(val_data_list)
# Out:
# 40

# %%
predict_svm(train_data_list, val_data_list, train_class_list, val_class_list)
# Out:
# Training of SVM started
#
#
# ACCURACY Score for  SVM 0.925
